# %% [markdown]
# # Important Jupyter shortcut
# tab to give function methods
# shift&tab parameter and help
# command&/ to comment ⌘/: comment

# %%
# # Load the necessary packages
import pandas as pd
import numpy as np
import scipy.stats as st

# %%
mydata = pd.read_csv('/content/xAPI-Edu-Data (1).csv')

# %%
mydata.tail(10)
# Out:
#     gender NationalITy PlaceofBirth       StageID GradeID SectionID  \
# 470      M   Palestine       Jordan  MiddleSchool    G-08         A
# 471      M   Palestine       Jordan  MiddleSchool    G-08         A
# 472      M   Palestine    Palestine  MiddleSchool    G-08         A
# 473      M   Palestine    Palestine  MiddleSchool    G-08         A
# 474      F      Jordan       Jordan  MiddleSchool    G-08         A
# 475      F      Jordan       Jordan  MiddleSchool    G-08         A
# 476      F      Jordan       Jordan  MiddleSchool    G-08         A
# 477      F      Jordan       Jordan  MiddleSchool    G-08         A
# 478      F      Jordan       Jordan  MiddleSchool    G-08         A
# 479      F      Jordan       Jordan  MiddleSchool    G-08         A
#
#          Topic Semester Relation  raisedhands  VisITedResources  \
# 470    History        F   Father           81                86
# 471    History        S   Father           78                82
# ...

# %%
# mydata.head()
mydata.columns
#mydata.info()
# Out:
# Index(['gender', 'NationalITy', 'PlaceofBirth', 'StageID', 'GradeID',
#        'SectionID', 'Topic', 'Semester', 'Relation', 'raisedhands',
#        'VisITedResources', 'AnnouncementsView', 'Discussion',
#        'ParentAnsweringSurvey', 'ParentschoolSatisfaction',
#        'StudentAbsenceDays', 'Class'],
#       dtype='object')

# %%
mydata.describe()
# Out:
#        raisedhands  VisITedResources  AnnouncementsView  Discussion
# count   480.000000        480.000000         480.000000  480.000000
# mean     46.775000         54.797917          37.918750   43.283333
# std      30.779223         33.080007          26.611244   27.637735
# min       0.000000          0.000000           0.000000    1.000000
# 25%      15.750000         20.000000          14.000000   20.000000
# 50%      50.000000         65.000000          33.000000   39.000000
# 75%      75.000000         84.000000          58.000000   70.000000
# max     100.000000         99.000000          98.000000   99.000000

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

mydata.hist(figsize=(30,40))
# Out:
# array([[<Axes: title={'center': 'raisedhands'}>,
#         <Axes: title={'center': 'VisITedResources'}>],
#        [<Axes: title={'center': 'AnnouncementsView'}>,
#         <Axes: title={'center': 'Discussion'}>]], dtype=object)

# %%
import seaborn as sns

sns.boxplot(x="NationalITy", y="raisedhands", data=mydata)
# Out:
# <Axes: xlabel='NationalITy', ylabel='raisedhands'>

# %%
pd.crosstab(mydata['gender'],mydata["Relation"] )
# Out:
# Relation  Father  Mum
# gender
# F             81   94
# M            202  103

# %%
sns.countplot(x="Semester", hue="Topic", data=mydata)
# Out:
# <Axes: xlabel='Semester', ylabel='count'>

# %%
pd.pivot_table(mydata, index=['NationalITy', 'gender'],
                     columns=[ 'Topic'], aggfunc=len)
# Out:
#                    AnnouncementsView                                           \
# Topic                         Arabic Biology Chemistry English French Geology
# NationalITy gender
# Egypt       F                    NaN     NaN       NaN     NaN    NaN     NaN
#             M                    NaN     NaN       NaN     1.0    2.0     NaN
# Iran        F                    NaN     NaN       NaN     NaN    NaN     NaN
#             M                    NaN     NaN       NaN     NaN    2.0     NaN
# Iraq        F                    2.0     2.0       NaN     NaN    2.0     NaN
#             M                    4.0     2.0       2.0     2.0    NaN     2.0
# Jordan      F                    4.0     4.0      12.0     9.0   17.0    10.0
#             M                   17.0    12.0      10.0     8.0   16.0    10.0
# KW          F                    5.0     NaN       NaN     7.0    NaN     NaN
#             M                   15.0     NaN       NaN     8.0    5.0     NaN
# ...

# %%
pd.pivot_table(mydata,'raisedhands', index=['NationalITy', 'gender'],
                     columns=[ 'Topic'])
# Out:
# Topic                  Arabic    Biology  Chemistry    English     French  \
# NationalITy gender
# Egypt       F             NaN        NaN        NaN        NaN        NaN
#             M             NaN        NaN        NaN  19.000000   6.000000
# Iran        F             NaN        NaN        NaN        NaN        NaN
#             M             NaN        NaN        NaN        NaN  15.000000
# Iraq        F       84.000000  88.000000        NaN        NaN  16.500000
#             M       74.250000  93.500000  85.000000  74.000000        NaN
# Jordan      F        9.000000  76.750000  47.416667  75.111111  41.117647
#             M       16.882353  53.000000  64.300000  25.375000  35.437500
# KW          F       50.400000        NaN        NaN  33.000000        NaN
#             M       52.266667        NaN        NaN  27.125000  48.200000
# Lybia       F             NaN   9.500000        NaN        NaN        NaN
# ...

# %%
mydata['Discussion'].std()
# Out:
# 27.637735038376356

# %%
mydata['Discussion'].mean()
# Out:
# np.float64(43.28333333333333)

# %%
sns.displot(mydata['Discussion'])

# %%
mydata.hist(by='gender',column = 'Topic',color='green')
# Out:
# array([<Axes: title={'center': 'F'}>, <Axes: title={'center': 'M'}>],
#       dtype=object)

# %%
mydata.hist(by='gender',column = 'Topic', figsize=(20,30), color='red')
# Out:
# array([<Axes: title={'center': 'F'}>, <Axes: title={'center': 'M'}>],
#       dtype=object)

# %%
sns.pairplot(mydata)

# %%
fig, ax = plt.subplots()
_ = plt.hist(mydata.raisedhands, color = 'red')

# %%
fig, ax = plt.subplots()
plt.axvline(x = mydata.Discussion.mean(), color='orange')
_ = plt.hist(mydata.Discussion, color = 'lightgray')

# %% [markdown]
# <style>
#   ul {
#     background-color: black;
#   }
#
# <div>
# <span style="color: pink;">
# <h2> Project: concider specification of your dataset </h2>
#     <h3>
#     <ul>
#   <li>Apply all above codes</li>
#   <li>Allways be creative to find interested information</li>
#   <li> Arrange and clean up your GitHub</li>
#     </ul>
#     </h3>
# </div>
#     </style>

# %%
fig, ax = plt.subplots()
plt.axvline(x = np.mean(mydata.Discussion), color='orange')
plt.axvline(x = np.median(mydata.Discussion), color='green')
_ = plt.hist(mydata.Discussion, color = 'lightgray')

# %%
mydata.Discussion.var()
# Out:
# 763.8443980514961

# %%
sigma = mydata.Discussion.std()
sigma
# Out:
# 27.637735038376356

# %%
xbar = mydata.Discussion.mean()

# %%
fig, ax = plt.subplots()
plt.axvline(x = xbar, color='orange')
plt.axvline(x = xbar+sigma, color='olivedrab')
plt.axvline(x = xbar-sigma, color='olivedrab')
_ = plt.hist(mydata.Discussion, color = 'lightgray')

# %%
st.sem(mydata.Discussion)
# Out:
# np.float64(1.2614842432391367)
